# %%
from ultralytics import YOLO
import torch
from pathlib import Path

# %%
model_path = "./best.pt"

# %%
model = YOLO(model_path)
device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", device)
# Out:
# Using device: cuda

# %%
def check_part(image_path, conf_threshold=0.5):
    results = model.predict(image_path, device=device, verbose=False, conf=conf_threshold)
    if not results:
        return False

    res = results[0]
    if res.boxes is None or len(res.boxes) == 0:
        return False
    for box in res.boxes:
        cls_id = int(box.cls[0]) if hasattr(box, "cls") else -1
        conf = float(box.conf[0]) if hasattr(box, "conf") else 0.0
        if cls_id == 0 and conf >= conf_threshold:
            return True

    return False
test_img = "/home/king/Downloads/833297504-40.jpg"
present = check_part(test_img)
print(test_img, "->", "PART_PRESENT" if present else "NO_PART")
# Out:
# /home/king/Downloads/833297504-40.jpg -> PART_PRESENT

# %%
from pathlib import Path

images_dir = Path("/home/king/OK1")  # TODO: set this if needed
image_exts = {".jpg", ".jpeg", ".png", ".bmp"}

image_paths = [
    p for p in images_dir.rglob("*")
    if p.suffix.lower() in image_exts
]

print(f"Found {len(image_paths)} images")

for img_path in sorted(image_paths):
    present = check_part(str(img_path))
    print(img_path.name, "->", "PART_PRESENT" if present else "NO_PART")
# Out:
# Found 60 images
# IMG20260202124223_BURST000_COVER.jpg -> PART_PRESENT
# IMG20260202124223_BURST001.jpg -> PART_PRESENT
# IMG20260202124223_BURST002.jpg -> PART_PRESENT
# IMG20260202124223_BURST003.jpg -> PART_PRESENT
# IMG20260202124223_BURST004.jpg -> PART_PRESENT
# IMG20260202124223_BURST005.jpg -> PART_PRESENT
# IMG20260202124223_BURST006.jpg -> PART_PRESENT
# IMG20260202124223_BURST007.jpg -> PART_PRESENT
# IMG20260202124223_BURST008.jpg -> PART_PRESENT
# IMG20260202124223_BURST009.jpg -> PART_PRESENT
# IMG20260202124223_BURST010.jpg -> PART_PRESENT
# IMG20260202124223_BURST011.jpg -> PART_PRESENT
# IMG20260202124223_BURST012.jpg -> PART_PRESENT
# IMG20260202124223_BURST013.jpg -> PART_PRESENT
# IMG20260202124223_BURST014.jpg -> PART_PRESENT
# IMG20260202124223_BURST015.jpg -> PART_PRESENT
# IMG20260202124223_BURST016.jpg -> PART_PRESENT
# IMG20260202124223_BURST017.jpg -> PART_PRESENT
# IMG20260202124223_BURST018.jpg -> PART_PRESENT
# IMG20260202124223_BURST019.jpg -> PART_PRESENT
# IMG20260202124230_BURST000_COVER.jpg -> PART_PRESENT
# IMG20260202124230_BURST001.jpg -> PART_PRESENT
# IMG20260202124230_BURST002.jpg -> PART_PRESENT
# IMG20260202124230_BURST003.jpg -> PART_PRESENT
# IMG20260202124230_BURST004.jpg -> PART_PRESENT
# IMG20260202124230_BURST005.jpg -> PART_PRESENT
# IMG20260202124230_BURST006.jpg -> PART_PRESENT
# IMG20260202124230_BURST007.jpg -> PART_PRESENT
# IMG20260202124230_BURST008.jpg -> PART_PRESENT
# IMG20260202124230_BURST009.jpg -> PART_PRESENT
# IMG20260202124230_BURST010.jpg -> PART_PRESENT
# IMG20260202124230_BURST011.jpg -> PART_PRESENT
# IMG20260202124230_BURST012.jpg -> PART_PRESENT
# IMG20260202124230_BURST013.jpg -> PART_PRESENT
# IMG20260202124230_BURST014.jpg -> PART_PRESENT
# IMG20260202124230_BURST015.jpg -> PART_PRESENT
# IMG20260202124230_BURST016.jpg -> PART_PRESENT
# IMG20260202124230_BURST017.jpg -> PART_PRESENT
# IMG20260202124230_BURST018.jpg -> PART_PRESENT
# IMG20260202124230_BURST019.jpg -> PART_PRESENT
# IMG20260202124240_BURST000_COVER.jpg -> PART_PRESENT
# IMG20260202124240_BURST001.jpg -> PART_PRESENT
# IMG20260202124240_BURST002.jpg -> PART_PRESENT
# IMG20260202124240_BURST003.jpg -> PART_PRESENT
# IMG20260202124240_BURST004.jpg -> PART_PRESENT
# IMG20260202124240_BURST005.jpg -> PART_PRESENT
# IMG20260202124240_BURST006.jpg -> PART_PRESENT
# IMG20260202124240_BURST007.jpg -> PART_PRESENT
# IMG20260202124240_BURST008.jpg -> PART_PRESENT
# IMG20260202124240_BURST009.jpg -> PART_PRESENT
# IMG20260202124240_BURST010.jpg -> PART_PRESENT
# IMG20260202124240_BURST011.jpg -> PART_PRESENT
# IMG20260202124240_BURST012.jpg -> PART_PRESENT
# IMG20260202124240_BURST013.jpg -> PART_PRESENT
# IMG20260202124240_BURST014.jpg -> PART_PRESENT
# IMG20260202124240_BURST015.jpg -> PART_PRESENT
# IMG20260202124240_BURST016.jpg -> PART_PRESENT
# IMG20260202124240_BURST017.jpg -> PART_PRESENT
# IMG20260202124240_BURST018.jpg -> PART_PRESENT
# IMG20260202124240_BURST019.jpg -> PART_PRESENT
