# %%
from ultralytics import YOLO
import torch

# %%
data_yaml = "/home/king/VisionM/VisionBackend/datasets/APInfotech/CBP/v2/data.yaml"
model_name = "yolov8n.pt"

epochs = 50
batch = 16
imgsz = 640
workers = 4
project = "runs/train"
run_name = "exp"
exist_ok = True

# %%
device = "0" if torch.cuda.is_available() else "cpu"
print("Using device:", device)
model = YOLO(model_name)
# Out:
# Using device: 0
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 22.1MB/s 0.3s.2s<0.1s1s

# %%
results = model.train(
    data=data_yaml,
    epochs=epochs,
    batch=batch,
    imgsz=imgsz,
    workers=workers,
    project=project,
    name=run_name,
    exist_ok=exist_ok,
    device=device,
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.7 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.6 🚀 Python-3.14.2 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 7808MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/home/king/VisionM/VisionBackend/datasets/APInfotech/CBP/v2/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=exp, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs/train, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/home/king/Local/runs/detect/runs/train/exp, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751897  ultralytics.nn.modules.head.Detect           [3, 16, None, [64, 128, 256]]
# Model summary: 130 layers, 3,011,433 parameters, 3,011,417 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 19.2MB/s 0.3s.2s<0.1s1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.1±0.1 ms, read: 977.2±188.5 MB/s, size: 242.6 KB)
# train: Scanning /home/king/VisionM/VisionBackend/datasets/APInfotech/CBP/v2/labels/train.cache... 825 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 825/825 216.3Mit/s 0.0s
# val: Fast image access ✅ (ping: 0.1±0.1 ms, read: 749.7±63.4 MB/s, size: 256.4 KB)
# val: Scanning /home/king/VisionM/VisionBackend/datasets/APInfotech/CBP/v2/labels/val.cache... 207 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 207/207 57.9Mit/s 0.0s
# Plotting labels to /home/king/Local/runs/detect/runs/train/exp/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: MuSGD(lr=0.001429, momentum=0.9) with parameter groups 0 weight(decay=0.0), 0 weight(decay=0.0005), 0 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to /home/king/Local/runs/detect/runs/train/exp
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      2.27G      2.752       4.75      2.723         17        640: 100% ━━━━━━━━━━━━ 52/52 3.0it/s 17.2s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 5.4it/s 1.3s0.2s
#                    all        207        207    0.00176      0.554     0.0104    0.00219
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50       2.5G      2.298      4.309      2.262         12        640: 100% ━━━━━━━━━━━━ 52/52 4.1it/s 12.7s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 7.1it/s 1.0s0.2s
#                    all        207        207     0.0024      0.727     0.0699     0.0282
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      2.52G      1.777      3.759      1.782         18        640: 100% ━━━━━━━━━━━━ 52/52 3.6it/s 14.5s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 4.0it/s 1.7s0.2s
#                    all        207        207      0.897      0.246      0.296      0.156
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      2.54G      1.558      3.068      1.592         15        640: 100% ━━━━━━━━━━━━ 52/52 7.2it/s 7.2s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 6.9it/s 1.0s0.2s
#                    all        207        207      0.478      0.453      0.514      0.264
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      2.55G      1.398      2.586      1.475         17        640: 100% ━━━━━━━━━━━━ 52/52 4.3it/s 12.0s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 7.3it/s 1.0s0.2s
#                    all        207        207       0.71      0.672      0.734      0.467
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      2.57G      1.297      2.225      1.399         17        640: 100% ━━━━━━━━━━━━ 52/52 3.8it/s 13.6s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.9it/s 2.4s0.4s
#                    all        207        207      0.743      0.932      0.895      0.565
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      2.58G      1.239      1.948      1.334         12        640: 100% ━━━━━━━━━━━━ 52/52 7.2it/s 7.2s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.4it/s 2.9s0.5s
#                    all        207        207       0.88      0.957      0.971      0.673
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50       2.6G       1.15      1.743      1.294         22        640: 100% ━━━━━━━━━━━━ 52/52 4.1it/s 12.6s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 7.5it/s 0.9s0.2s
#                    all        207        207      0.928      0.963      0.975      0.711
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      2.62G      1.103      1.576      1.249         15        640: 100% ━━━━━━━━━━━━ 52/52 9.8it/s 5.3s<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 11.1it/s 0.6s.1s
#                    all        207        207      0.928      0.975      0.981      0.688
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      2.63G      1.049      1.475      1.227         18        640: 100% ━━━━━━━━━━━━ 52/52 9.9it/s 5.3s<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 11.6it/s 0.6s.1s
#                    all        207        207      0.916      0.991      0.982      0.737
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      2.65G     0.9888      1.414      1.191         18        640: 100% ━━━━━━━━━━━━ 52/52 9.9it/s 5.2s<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 11.6it/s 0.6s.1s
#                    all        207        207      0.937      0.977      0.988       0.78
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      2.67G     0.9691      1.362      1.178         14        640: 100% ━━━━━━━━━━━━ 52/52 9.3it/s 5.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 11.0it/s 0.6s.3s
#                    all        207        207      0.918          1      0.988      0.781
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      2.69G     0.9329      1.315      1.165         16        640: 100% ━━━━━━━━━━━━ 52/52 9.6it/s 5.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 11.1it/s 0.6s.1s
#                    all        207        207      0.966      0.955      0.986      0.771
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      2.71G     0.9549      1.276      1.155          9        640: 100% ━━━━━━━━━━━━ 52/52 9.6it/s 5.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 11.5it/s 0.6s.1s
#                    all        207        207      0.943      0.974      0.984      0.795
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      2.71G     0.8922      1.203      1.124         19        640: 100% ━━━━━━━━━━━━ 52/52 9.5it/s 5.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 11.2it/s 0.6s.3s
#                    all        207        207      0.957      0.956      0.989      0.808
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      2.71G     0.8862       1.19      1.116         20        640: 100% ━━━━━━━━━━━━ 52/52 9.5it/s 5.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 11.5it/s 0.6s.1s
#                    all        207        207      0.918      0.995      0.976      0.806
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      2.71G     0.8548      1.166        1.1         15        640: 100% ━━━━━━━━━━━━ 52/52 9.6it/s 5.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 11.3it/s 0.6s.1s
#                    all        207        207      0.962      0.977      0.982      0.806
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50      2.71G     0.8512      1.099       1.09         19        640: 100% ━━━━━━━━━━━━ 52/52 9.6it/s 5.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 11.3it/s 0.6s.1s
#                    all        207        207      0.967      0.965       0.99      0.821
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50      2.71G     0.8052       1.07      1.062         16        640: 100% ━━━━━━━━━━━━ 52/52 9.5it/s 5.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 11.7it/s 0.6s.1s
#                    all        207        207       0.93      0.999      0.987      0.826
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      2.71G     0.8049      1.074      1.077         16        640: 100% ━━━━━━━━━━━━ 52/52 9.5it/s 5.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 11.6it/s 0.6s.1s
#                    all        207        207      0.963      0.979       0.99      0.819
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50      2.71G     0.7897      1.032       1.06         17        640: 100% ━━━━━━━━━━━━ 52/52 9.5it/s 5.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 11.2it/s 0.6s.3s
#                    all        207        207      0.983      0.955      0.989      0.836
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50      2.71G     0.7702     0.9973       1.05         21        640: 100% ━━━━━━━━━━━━ 52/52 9.6it/s 5.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 11.5it/s 0.6s.1s
#                    all        207        207      0.963      0.986      0.992      0.843
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50      2.71G       0.76       1.02      1.045         20        640: 100% ━━━━━━━━━━━━ 52/52 9.6it/s 5.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 11.4it/s 0.6s.1s
#                    all        207        207      0.968      0.981      0.992      0.848
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50      2.71G      0.747     0.9488       1.04         18        640: 100% ━━━━━━━━━━━━ 52/52 9.6it/s 5.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 11.6it/s 0.6s.1s
#                    all        207        207      0.967      0.966      0.988      0.844
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50      2.71G     0.7243     0.9107      1.017         18        640: 100% ━━━━━━━━━━━━ 52/52 9.5it/s 5.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 11.4it/s 0.6s.1s
#                    all        207        207      0.972      0.966      0.991      0.847
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50      2.71G     0.7432     0.9506      1.029         14        640: 100% ━━━━━━━━━━━━ 52/52 9.6it/s 5.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 11.6it/s 0.6s.1s
#                    all        207        207      0.972      0.973      0.991      0.843
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      2.71G      0.711     0.8924      1.019         20        640: 100% ━━━━━━━━━━━━ 52/52 9.6it/s 5.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 11.5it/s 0.6s.1s
#                    all        207        207      0.971      0.981       0.99      0.844
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50      2.71G     0.6872     0.8984      1.009          9        640: 100% ━━━━━━━━━━━━ 52/52 9.6it/s 5.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 11.6it/s 0.6s.1s
#                    all        207        207      0.969      0.985      0.991      0.866
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50      2.71G     0.6978     0.8905      1.011         15        640: 100% ━━━━━━━━━━━━ 52/52 9.6it/s 5.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 11.6it/s 0.6s.1s
#                    all        207        207      0.963      0.962       0.99      0.857
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      2.71G     0.6899     0.8604      1.005         16        640: 100% ━━━━━━━━━━━━ 52/52 9.5it/s 5.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 11.6it/s 0.6s.1s
#                    all        207        207      0.949          1      0.992      0.871
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50      2.73G     0.6862     0.8594     0.9995         16        640: 100% ━━━━━━━━━━━━ 52/52 9.5it/s 5.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 11.5it/s 0.6s.1s
#                    all        207        207      0.972      0.985      0.991      0.871
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50      2.75G     0.6574     0.8581     0.9952         18        640: 100% ━━━━━━━━━━━━ 52/52 9.6it/s 5.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 11.2it/s 0.6s.1s
#                    all        207        207      0.962      0.985      0.991      0.872
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50      2.77G     0.6513     0.8319     0.9925         17        640: 100% ━━━━━━━━━━━━ 52/52 9.6it/s 5.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 11.5it/s 0.6s.1s
#                    all        207        207      0.953      0.994      0.991      0.863
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50      2.78G     0.6273     0.8259     0.9843         18        640: 100% ━━━━━━━━━━━━ 52/52 9.6it/s 5.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 11.4it/s 0.6s.1s
#                    all        207        207      0.973      0.981      0.993      0.876
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50       2.8G     0.6316     0.8336     0.9737          8        640: 100% ━━━━━━━━━━━━ 52/52 9.5it/s 5.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 11.6it/s 0.6s.1s
#                    all        207        207       0.96      0.993      0.993      0.873
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50      2.82G     0.6246     0.8152     0.9761         12        640: 100% ━━━━━━━━━━━━ 52/52 9.6it/s 5.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 11.5it/s 0.6s.1s
#                    all        207        207      0.997      0.947      0.992      0.877
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      2.83G     0.6229     0.7944     0.9784         16        640: 100% ━━━━━━━━━━━━ 52/52 9.6it/s 5.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 11.7it/s 0.6s.1s
#                    all        207        207      0.965      0.995      0.993       0.88
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      2.85G     0.6138     0.7703     0.9644         18        640: 100% ━━━━━━━━━━━━ 52/52 9.5it/s 5.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 11.5it/s 0.6s.1s
#                    all        207        207      0.978      0.991      0.994      0.891
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      2.87G     0.6277     0.7995     0.9746         26        640: 100% ━━━━━━━━━━━━ 52/52 9.6it/s 5.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 11.4it/s 0.6s.1s
#                    all        207        207      0.978       0.98      0.993        0.9
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      2.88G     0.5943     0.7724     0.9561         15        640: 100% ━━━━━━━━━━━━ 52/52 9.5it/s 5.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 11.6it/s 0.6s.1s
#                    all        207        207      0.973      0.985      0.992      0.891
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50       2.9G     0.5269     0.8153     0.9208          9        640: 100% ━━━━━━━━━━━━ 52/52 9.1it/s 5.7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 10.9it/s 0.6s.1s
#                    all        207        207      0.983      0.983      0.994      0.891
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      2.92G     0.5036     0.8174     0.9037          9        640: 100% ━━━━━━━━━━━━ 52/52 9.6it/s 5.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 11.3it/s 0.6s.1s
#                    all        207        207      0.977       0.98      0.994      0.892
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      2.93G      0.476     0.7857     0.8934          9        640: 100% ━━━━━━━━━━━━ 52/52 9.6it/s 5.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 11.5it/s 0.6s.1s
#                    all        207        207      0.969      0.995      0.994        0.9
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      2.95G     0.4658     0.7789     0.8883          9        640: 100% ━━━━━━━━━━━━ 52/52 9.6it/s 5.4s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 11.6it/s 0.6s.1s
#                    all        207        207      0.967      0.997      0.994      0.898
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      2.97G     0.4439     0.7665     0.8764          9        640: 100% ━━━━━━━━━━━━ 52/52 9.6it/s 5.4s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 11.2it/s 0.6s.1s
#                    all        207        207       0.97      0.994      0.994      0.895
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      2.97G     0.4388     0.7561     0.8768          9        640: 100% ━━━━━━━━━━━━ 52/52 9.5it/s 5.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 11.2it/s 0.6s.3s
#                    all        207        207      0.969      0.995      0.994      0.906
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      2.97G     0.4254     0.7467     0.8721          9        640: 100% ━━━━━━━━━━━━ 52/52 9.5it/s 5.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 11.6it/s 0.6s.1s
#                    all        207        207      0.968      0.995      0.994        0.9
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      2.97G     0.4277     0.7356     0.8755          9        640: 100% ━━━━━━━━━━━━ 52/52 9.6it/s 5.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 11.5it/s 0.6s.1s
#                    all        207        207      0.969      0.995      0.994       0.91
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      2.97G     0.4224      0.739     0.8674          9        640: 100% ━━━━━━━━━━━━ 52/52 9.6it/s 5.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 11.6it/s 0.6s.1s
#                    all        207        207      0.969          1      0.994       0.91
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      2.97G     0.4429     0.7474     0.8819          9        640: 100% ━━━━━━━━━━━━ 52/52 9.6it/s 5.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 11.6it/s 0.6s.1s
#                    all        207        207       0.97      0.998      0.994      0.906
#
# 50 epochs completed in 0.104 hours.
# Optimizer stripped from /home/king/Local/runs/detect/runs/train/exp/weights/last.pt, 6.3MB
# Optimizer stripped from /home/king/Local/runs/detect/runs/train/exp/weights/best.pt, 6.3MB
#
# Validating /home/king/Local/runs/detect/runs/train/exp/weights/best.pt...
# Ultralytics 8.4.6 🚀 Python-3.14.2 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 7808MiB)
# Model summary (fused): 73 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 6.9it/s 1.0s0.2s
#                    all        207        207      0.969      0.995      0.994      0.909
#                class_0         71         71          1      0.985      0.995      0.881
#                class_1         61         61      0.917          1      0.992      0.913
#                class_2         75         75      0.991          1      0.995      0.932
# Speed: 0.2ms preprocess, 2.1ms inference, 0.0ms loss, 1.1ms postprocess per image
# Results saved to /home/king/Local/runs/detect/runs/train/exp
